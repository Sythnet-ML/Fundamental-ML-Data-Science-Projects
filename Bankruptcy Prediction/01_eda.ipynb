# %% [markdown]
# # Bankruptcy Prediction - Exploratory Data Analysis
#
# *Target:* `Bankrupt` ( `No` = Healthy, `Yes` = Bankrupt)

# %% [markdown]
# ## 1. Import and Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams.update({'figure.figsize': (10, 6)})

import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"data\bankruptcy.csv")
print(df.shape)


df.head()
# Out:
# (6819, 95)
#   Bankrupt  ROA_C_Before_Interest_Depreciation  \
# 0       No                            0.571832
# 1       No                            0.494613
# 2       No                            0.465315
# 3       No                            0.506118
# 4       No                            0.539170
#
#    ROA_A_Before_Interest_After_Tax  \
# 0                         0.642390
# 1                         0.549771
# 2                         0.515645
# 3                         0.556912
# 4                         0.593273
#
#    ROA_B_Before_Interest_Depreciation_After_Tax  Operating_Gross_Margin  \
# 0                                      0.634670                0.626169
# 1                                      0.543445                0.602091
# 2                                      0.511591                0.593782
# 3                                      0.547727                0.615820
# 4                                      0.586273                0.606949
#
#    Realized_Sales_Gross_Margin  Operating_Profit_Rate  \
# 0                     0.626169               0.999232
# 1                     0.602091               0.998986
# 2                     0.593782               0.998961
# 3                     0.615820               0.999169
# 4                     0.606949               0.999077
#
#    PreTax_Net_Interest_Rate  AfterTax_Net_Interest_Rate  \
# 0                  0.797749                    0.809653
# 1                  0.797405                    0.809328
# 2                  0.797354                    0.809277
# 3                  0.797528                    0.809401
# 4                  0.797485                    0.809394
#
#    NonIndustry_Income_Expenditure_Revenue  ...  Liability_Assets_Flag  \
# 0                                0.303602  ...                      0
# 1                                0.303516  ...                      0
# 2                                0.303480  ...                      0
# 3                                0.303348  ...                      0
# 4                                0.303465  ...                      0
#
#    Net_Income_to_Total_Assets  Total_Assets_to_GNP_Price  NoCredit_Interval  \
# 0                    0.854406                   0.007801           0.623980
# 1                    0.804106                   0.007002           0.623701
# 2                    0.785955                   0.008955           0.623801
# 3                    0.810229                   0.000662           0.623844
# 4                    0.827668                   0.001374           0.623774
#
#    Gross_Profit_to_Sales  Net_Income_to_Stockholders_Equity  \
# 0               0.626165                           0.843256
# 1               0.602091                           0.840783
# 2               0.593777                           0.839341
# 3               0.615818                           0.840996
# 4               0.606948                           0.842516
#
#    Liability_to_Equity       DFL  Interest_Coverage_Ratio  Equity_to_Liability
# 0             0.275994  0.026797                 0.565185             0.083956
# 1             0.281189  0.027200                 0.566564             0.025107
# 2             0.278153  0.026630                 0.564252             0.038119
# 3             0.277714  0.026863                 0.565477             0.042154
# 4             0.279316  0.026818                 0.565285             0.031117
#
# [5 rows x 95 columns]

# %% [markdown]
# ## 2. Data Overview and Missing Values / Duplicate Search

# %%
print("Dtypes:")
print(df.dtypes.value_counts())
# Out:
# Dtypes:
# float64    93
# object      1
# int64       1
# Name: count, dtype: int64

# %%
df.describe(include='all').head(20).T
# Out:
#                                                count unique  top  freq  \
# Bankrupt                                        6819      2   No  6599
# ROA_C_Before_Interest_Depreciation            6819.0    NaN  NaN   NaN
# ROA_A_Before_Interest_After_Tax               6819.0    NaN  NaN   NaN
# ROA_B_Before_Interest_Depreciation_After_Tax  6819.0    NaN  NaN   NaN
# Operating_Gross_Margin                        6819.0    NaN  NaN   NaN
# ...                                              ...    ...  ...   ...
# Net_Income_to_Stockholders_Equity             6819.0    NaN  NaN   NaN
# Liability_to_Equity                           6819.0    NaN  NaN   NaN
# DFL                                           6819.0    NaN  NaN   NaN
# Interest_Coverage_Ratio                       6819.0    NaN  NaN   NaN
# Equity_to_Liability                           6819.0    NaN  NaN   NaN
#
#                                                   mean       std  min  \
# Bankrupt                                           NaN       NaN  NaN
# ROA_C_Before_Interest_Depreciation             0.50518  0.060686  0.0
# ROA_A_Before_Interest_After_Tax               0.558625   0.06562  0.0
# ROA_B_Before_Interest_Depreciation_After_Tax  0.553589  0.061595  0.0
# Operating_Gross_Margin                        0.607948  0.016934  0.0
# ...                                                ...       ...  ...
# Net_Income_to_Stockholders_Equity             0.840402  0.014523  0.0
# Liability_to_Equity                           0.280365  0.014463  0.0
# DFL                                           0.027541  0.015668  0.0
# Interest_Coverage_Ratio                       0.565358  0.013214  0.0
# Equity_to_Liability                           0.047578  0.050014  0.0
#
#                                                    25%       50%       75%  \
# Bankrupt                                           NaN       NaN       NaN
# ROA_C_Before_Interest_Depreciation            0.476527  0.502706  0.535563
# ROA_A_Before_Interest_After_Tax               0.535543  0.559802  0.589157
# ROA_B_Before_Interest_Depreciation_After_Tax  0.527277  0.552278  0.584105
# Operating_Gross_Margin                        0.600445  0.605997  0.613914
# ...                                                ...       ...       ...
# Net_Income_to_Stockholders_Equity             0.840115  0.841179  0.842357
# Liability_to_Equity                           0.276944  0.278778  0.281449
# DFL                                           0.026791  0.026808  0.026913
# Interest_Coverage_Ratio                       0.565158  0.565252  0.565725
# Equity_to_Liability                           0.024477  0.033798  0.052838
#
#                                               max
# Bankrupt                                      NaN
# ROA_C_Before_Interest_Depreciation            1.0
# ROA_A_Before_Interest_After_Tax               1.0
# ROA_B_Before_Interest_Depreciation_After_Tax  1.0
# Operating_Gross_Margin                        1.0
# ...                                           ...
# Net_Income_to_Stockholders_Equity             1.0
# Liability_to_Equity                           1.0
# DFL                                           1.0
# Interest_Coverage_Ratio                       1.0
# Equity_to_Liability                           1.0
#
# [95 rows x 11 columns]

# %%
print("Columns With Missing Values:")
print(df.isnull().sum())
print(f"Total Missing Values: {df.isnull().sum().sum()}")


print(f'\nColumns With Duplicates: ')
print(df.duplicated().astype(int))
print(f"Total Number of Duplicated Rows {df.duplicated().sum()}")
# Out:
# Columns With Missing Values:
# Bankrupt                                        0
# ROA_C_Before_Interest_Depreciation              0
# ROA_A_Before_Interest_After_Tax                 0
# ROA_B_Before_Interest_Depreciation_After_Tax    0
# Operating_Gross_Margin                          0
#                                                ..
# Net_Income_to_Stockholders_Equity               0
# Liability_to_Equity                             0
# DFL                                             0
# Interest_Coverage_Ratio                         0
# Equity_to_Liability                             0
# Length: 95, dtype: int64
# Total Missing Values: 0
#
# Columns With Duplicates:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6814    0
# 6815    0
# 6816    0
# 6817    0
# 6818    0
# Length: 6819, dtype: int64
# Total Number of Duplicated Rows 0

# %% [markdown]
# ## 3. Target Variable Analysis

# %%
df['Bankrupt'] = df['Bankrupt'].map({'No' : 0, 'Yes': 1})

# %%
fig , axes = plt.subplots(1,2 , figsize =(12, 4))

target_count = df['Bankrupt'].value_counts().sort_index()

sns.countplot(x=df['Bankrupt'], palette='Set2', ax=axes[0], legend= True)
axes[0].set_title("Bankrupt Count Plot")
axes[0].set_xticklabels(['Healthy','Bankrupt'])
for i , v in enumerate(target_count):
    axes[0].text(i, v + 100, str(v), ha='center', fontsize=12)
    
axes[1].pie(target_count,labels =['Healthy','Bankrupt'], startangle = 90)
axes[1].set_title("Class Proportion")

plt.tight_layout();     plt.show()

# %%
print("Class Balance (%): ")
print(f"Healthy : {(df["Bankrupt"] == 0).sum() / len(df['Bankrupt']) * 100 :.2f}%")
print(f"Bankrupt : {((df["Bankrupt"] == 1).sum() / len(df['Bankrupt'])* 100).round(2)}%")
# Out:
# Class Balance (%):
# Healthy : 96.77%
# Bankrupt : 3.23%

# %% [markdown]
# ## 4. Univariate Variable Analysis - Numerical Columns

# %%
num_col = df.drop(columns = "Bankrupt").columns.to_list()
print(num_col)
# Out:
# ['ROA_C_Before_Interest_Depreciation', 'ROA_A_Before_Interest_After_Tax', 'ROA_B_Before_Interest_Depreciation_After_Tax', 'Operating_Gross_Margin', 'Realized_Sales_Gross_Margin', 'Operating_Profit_Rate', 'PreTax_Net_Interest_Rate', 'AfterTax_Net_Interest_Rate', 'NonIndustry_Income_Expenditure_Revenue', 'Continuous_Interest_Rate_After_Tax', 'Operating_Expense_Rate', 'R&D_Expense_Rate', 'Cash_Flow_Rate', 'InterestBearing_Debt_Interest_Rate', 'Tax_Rate_A', 'Net_Value_Per_Share_B', 'Net_Value_Per_Share_A', 'Net_Value_Per_Share_C', 'Persistent_EPS_Last_4_Seasons', 'Cash_Flow_Per_Share', 'Revenue_Per_Share', 'Operating_Profit_Per_Share', 'Net_Profit_Before_Tax_Per_Share', 'Realized_Sales_Gross_Profit_Growth_Rate', 'Operating_Profit_Growth_Rate', 'AfterTax_Net_Profit_Growth_Rate', 'Regular_Net_Profit_Growth_Rate', 'Continuous_Net_Profit_Growth_Rate', 'Total_Asset_Growth_Rate', 'Net_Value_Growth_Rate', 'Total_Asset_Return_Growth_Rate', 'Cash_Reinvestment_Percent', 'Current_Ratio', 'Quick_Ratio', 'Interest_Expense_Ratio', 'Total_Debt_to_Net_Worth', 'Debt_Ratio_Percent', 'Net_Worth_to_Assets', 'LongTerm_Fund_Suitability_Ratio_A', 'Borrowing_Dependency', 'Contingent_Liabilities_to_Net_Worth', 'Operating_Profit_to_PaidIn_Capital', 'Net_Profit_Before_Tax_to_PaidIn_Capital', 'Inventory_Accounts_Receivable_to_Net_Value', 'Total_Asset_Turnover', 'Accounts_Receivable_Turnover', 'Average_Collection_Days', 'Inventory_Turnover_Rate', 'Fixed_Assets_Turnover_Frequency', 'Net_Worth_Turnover_Rate', 'Revenue_Per_Person', 'Operating_Profit_Per_Person', 'Allocation_Rate_Per_Person', 'Working_Capital_to_Total_Assets', 'Quick_Assets_to_Total_Assets', 'Current_Assets_to_Total_Assets', 'Cash_to_Total_Assets', 'Quick_Assets_to_Current_Liability', 'Cash_to_Current_Liability', 'Current_Liability_to_Assets', 'Operating_Funds_to_Liability', 'Inventory_to_Working_Capital', 'Inventory_to_Current_Liability', 'Current_Liabilities_to_Liability', 'Working_Capital_to_Equity', 'Current_Liabilities_to_Equity', 'LongTerm_Liability_to_Current_Assets', 'Retained_Earnings_to_Total_Assets', 'Total_Income_to_Total_Expense', 'Total_Expense_to_Assets', 'Current_Asset_Turnover_Rate', 'Quick_Asset_Turnover_Rate', 'Working_Capital_Turnover_Rate', 'Cash_Turnover_Rate', 'Cash_Flow_to_Sales', 'Fixed_Assets_to_Assets', 'Current_Liability_to_Liability', 'Current_Liability_to_Equity', 'Equity_to_LongTerm_Liability', 'Cash_Flow_to_Total_Assets', 'Cash_Flow_to_Liability', 'CFO_to_Assets', 'Cash_Flow_to_Equity', 'Current_Liability_to_Current_Assets', 'Liability_Assets_Flag', 'Net_Income_to_Total_Assets', 'Total_Assets_to_GNP_Price', 'NoCredit_Interval', 'Gross_Profit_to_Sales', 'Net_Income_to_Stockholders_Equity', 'Liability_to_Equity', 'DFL', 'Interest_Coverage_Ratio', 'Equity_to_Liability']

# %%
df.describe(include= 'int64')
# Out:
#           Bankrupt  Liability_Assets_Flag
# count  6819.000000            6819.000000
# mean      0.032263               0.001173
# std       0.176710               0.034234
# min       0.000000               0.000000
# 25%       0.000000               0.000000
# 50%       0.000000               0.000000
# 75%       0.000000               0.000000
# max       1.000000               1.000000

# %%
stew_col= df.select_dtypes(include='number').drop(columns= 'Bankrupt')
skewedness = stew_col.skew().sort_values(ascending = False)
skew_col = skewedness[abs(skewedness) > 1]
not_skew = skewedness[abs(skewedness) < 1]

print("Features that are skewed:\n")
print(skew_col)
print("\nFeatures that are not skewed:")
print(not_skew)
# Out:
# Features that are skewed:
#
# Fixed_Assets_to_Assets                 82.577237
# Current_Ratio                          82.577237
# Total_Income_to_Total_Expense          82.332424
# Net_Value_Growth_Rate                  80.291844
# Contingent_Liabilities_to_Net_Worth    79.670620
#                                          ...
# PreTax_Net_Interest_Rate              -52.482867
# AfterTax_Net_Interest_Rate            -52.995744
# Continuous_Interest_Rate_After_Tax    -53.200121
# Operating_Profit_Rate                 -70.237164
# Operating_Profit_Growth_Rate          -71.688950
# Length: 81, dtype: float64
#
# Features that are not skewed:
# Debt_Ratio_Percent                              0.980796
# Cash_Turnover_Rate                              0.954117
# Quick_Assets_to_Total_Assets                    0.337315
# Current_Assets_to_Total_Assets                  0.075890
# Working_Capital_to_Total_Assets                -0.192311
# Cash_Flow_to_Total_Assets                      -0.228158
# ROA_C_Before_Interest_Depreciation             -0.323941
# CFO_to_Assets                                  -0.443762
# ROA_B_Before_Interest_Depreciation_After_Tax   -0.763564
# Current_Liabilities_to_Liability               -0.835047
# Current_Liability_to_Liability                 -0.835047
# Total_Asset_Growth_Rate                        -0.918791
# Net_Worth_to_Assets                            -0.980796
# dtype: float64

# %%
feature = "Fixed_Assets_to_Assets"

fig, ax = plt.subplots(1,2, figsize=(12,4))

ax[0].hist(df[feature], bins=30)
ax[0].set_title("Original")

ax[1].hist(np.log1p(df[feature]), bins=30)
ax[1].set_title("log1p")

plt.show()

# %% [markdown]
# As of the skewness , the `np.log1p()` did not really work much so i have to change to
# Yeo-Johnson Transformation ( PowerTransformer)

# %%
from sklearn.preprocessing import PowerTransformer

x_trans = df.copy()
pt = PowerTransformer()

x_trans = pt.fit_transform(x_trans[num_col])

# %%
fig, axes = plt.subplots(3, 4 , figsize=(20,16))

ncoln = num_col[:12]        # Use 10 Feature for the univariate analysis
axes = axes.flatten()

for i ,v in enumerate(ncoln):
    x_t = x_trans[:, num_col.index(v)]
    
    axes[i].hist(x_t, bins= 30, edgecolor= 'white', alpha =0.8, density=True)
    sns.kdeplot(x=x_t, ax=axes[i], color='purple', linewidth=1, label='KDE')
    
    axes[i].axvline(df[v].mean(), linestyle= '--', color='red', label = f"Mean: {df[v].mean().round(3)}", alpha= 0.5)
    axes[i].axvline(np.median(x_t), linestyle= '--', color='blue', label = f"Median: {np.median(x_t).round(3)}",  alpha= 0.5)

    axes[i].set_title(v);  axes[i].set_ylabel("Count")
    axes[i].legend()
    

plt.tight_layout()
plt.show()

# %%
# Check for Numerical Outliers
fig, axes = plt.subplots(4, 3,figsize= (20, 16))

axes= axes.flatten()
for i , v in enumerate(ncoln):
    sns.boxplot(x= x_trans[:, num_col.index(v)], color='lightcoral', ax =axes[i])
    axes[i].set_title(v)
    
plt.suptitle("OUTLIER DETECTION", fontweight= 'bold', fontsize = 20)
plt.tight_layout();     plt.show()

# %% [markdown]
# ## 5. Bivariate Analysis - Target Vs Feature
# Get the top features by correlation and pair them with the target `Bankrupt`

# %%
corr_data = df.corr()['Bankrupt'].abs().sort_values(ascending=False).drop('Bankrupt')

print("Top 5 Features with the Highest Corr_ value are: ")
print(corr_data[:5])
# Out:
# Top 5 Features with the Highest Corr_ value are:
# Net_Income_to_Total_Assets                      0.315457
# ROA_A_Before_Interest_After_Tax                 0.282941
# ROA_B_Before_Interest_Depreciation_After_Tax    0.273051
# ROA_C_Before_Interest_Depreciation              0.260807
# Debt_Ratio_Percent                              0.250161
# Name: Bankrupt, dtype: float64

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes= axes.flatten()

for i , v in enumerate(corr_data[:8].index):
    for j in range(0,2):
        sns.kdeplot(x=df[df['Bankrupt'] == j][v].dropna(), ax=axes[i], label=f'Bankrupt: {j}', linewidth=2)
        
        axes[i].hist([df[df['Bankrupt'] == j][v].dropna()],
                bins=20, edgecolor='white', alpha=0.8, label=['Healthy' if j == 0 else 'Bankrupt',],density=True)
        j += 1
    axes[i].set_title(v)
    axes[i].legend()

plt.tight_layout();     plt.show()

# %%
means = df.groupby("Bankrupt")[num_col].mean().T
means.columns = ["Healthy","Bankrupt"]

means['Differences'] = means.iloc[: ,0] - means.iloc[:,1]
means.sort_values(by= "Differences", key=abs, ascending=False).round(1)
# Out:
#                                               Healthy      Bankrupt  \
# Fixed_Assets_Turnover_Frequency          9.756574e+08  1.996603e+09
# Total_Asset_Growth_Rate                  5.531603e+09  4.803017e+09
# Quick_Asset_Turnover_Rate                2.147829e+09  2.640836e+09
# R&D_Expense_Rate                         1.961923e+09  1.605623e+09
# Cash_Turnover_Rate                       2.481653e+09  2.181733e+09
# ...                                               ...           ...
# Working_Capital_Turnover_Rate            6.000000e-01  6.000000e-01
# Inventory_to_Working_Capital             3.000000e-01  3.000000e-01
# Realized_Sales_Gross_Profit_Growth_Rate  0.000000e+00  0.000000e+00
# Cash_Flow_to_Sales                       7.000000e-01  7.000000e-01
# Operating_Profit_Rate                    1.000000e+00  1.000000e+00
#
#                                           Differences
# Fixed_Assets_Turnover_Frequency         -1.020945e+09
# Total_Asset_Growth_Rate                  7.285860e+08
# Quick_Asset_Turnover_Rate               -4.930069e+08
# R&D_Expense_Rate                         3.562993e+08
# Cash_Turnover_Rate                       2.999205e+08
# ...                                               ...
# Working_Capital_Turnover_Rate            0.000000e+00
# Inventory_to_Working_Capital             0.000000e+00
# Realized_Sales_Gross_Profit_Growth_Rate  0.000000e+00
# Cash_Flow_to_Sales                      -0.000000e+00
# Operating_Profit_Rate                    0.000000e+00
#
# [94 rows x 3 columns]

# %% [markdown]
# ## 6. Correlation Analysis
#
# Features Correlation with `Bankrupt`

# %%
fig, ax = plt.subplots(figsize= (20, 10))

top_15 = df.corr()['Bankrupt'].head(15).abs().sort_values(ascending=False).index.to_list()
top= df[top_15].corr()
mask = np.triu(top)

sns.heatmap(data=top, annot=True,fmt=".2f", ax= ax,mask= mask, cmap="coolwarm",center=0, linewidths=0.7, square=True, cbar_kws={'shrink': 0.5})
plt.suptitle("Correlation Analysis of Top 15 Most Important Features")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20,16))

imp = df.corr()['Bankrupt'].sort_values().drop('Bankrupt')
axes.barh(y=imp.index, width=imp.values, color=['skyblue' if x > 0 else 'lightcoral' for x in imp.values], edgecolor='black')
#imp.plot(kind='barh', ax=axes, color=['skyblue' if x > 0 else 'lightcoral' for x in imp.values], edgecolor='black')
axes.axvline(x=0, color='black', linewidth=1, label='Zero Line', alpha=0.7, linestyle='--')
axes.set_xlabel('Absolute Correlation with Bankrupt')
axes.set_ylabel('Features')
axes.legend()

plt.title("Feature Importance Based on Correlation with Target Variable")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Deep Dive

# %%
top_8 = df.corr()["Bankrupt"].sort_values(key= abs , ascending=False).drop("Bankrupt").head(8)

fig, axes = plt.subplots(2, 4, figsize =(14, 9))
axes= axes.flatten()
for i ,v in enumerate(top_8.index):
    sns.boxplot(x= df['Bankrupt'], y= df[v], ax=axes[i], palette= 'Set2')
    axes[i].set_title(f"{v}")
    

plt.tight_layout()
plt.show()

# %%
# Class Imbalance Level
print("Class Distribution:")

print(f"Healthy : {len(df[df['Bankrupt'] == 0])}, ({len(df[df['Bankrupt'] == 0]) / len(df) * 100:.2f}%)")
print(f"Bankrupt : {len(df[df['Bankrupt'] == 1])}, ({len(df[df['Bankrupt'] == 1]) / len(df) * 100:.2f}%)")

print(f"Class Imbalance Ratio (Healthy : Bankrupt): {((len(df[df['Bankrupt'] == 0])) / (len(df[df['Bankrupt'] == 1]))):.1f}:1")
# Out:
# Class Distribution:
# Healthy : 6599, (96.77%)
# Bankrupt : 220, (3.23%)
# Class Imbalance Ratio (Healthy : Bankrupt): 30.0:1

# %% [markdown]
# ## 8. Pair PLot of Feature

# %%
sample = df.sample(min(1000 , len(df)), random_state=42)
corr_data = df.corr()['Bankrupt'].abs().sort_values(ascending=False).index


sns.pairplot(sample[corr_data[:5]], hue='Bankrupt', diag_kind='kde', kind='reg', palette='Set2',
            plot_kws={'scatter_kws': {'alpha': 0.8, 's': 20}, 'line_kws': {'color': "#1DAA47", 'linewidth': 1}})
plt.suptitle('Pair-Plot for top 5 feature')

plt.tight_layout();     plt.show()

# %% [markdown]
# # Summary of the Key Findings

# %%
summary = pd.DataFrame({
    'Metric': ['Total samples', 'Total features', 'Class 0 count', 'Class 1 count',
              'Class imbalance ratio', 'Top correlated feature', 'Top correlation value'],
    'Value': [
        len(df),
        df.shape[1] - 1,
        int((df['Bankrupt'] == 0).sum()),
        int((df['Bankrupt'] == 1).sum()),
        f"{(df['Bankrupt'] == 0).sum() / max(1, (df['Bankrupt'] == 1).sum()):.2f}:1",
        corr_data[0],
        top_8[corr_data[1]].round(3),
    ],
})
summary
# Out:
#                    Metric     Value
# 0           Total samples      6819
# 1          Total features        94
# 2           Class 0 count      6599
# 3           Class 1 count       220
# 4   Class imbalance ratio   30.00:1
# 5  Top correlated feature  Bankrupt
# 6   Top correlation value    -0.315
